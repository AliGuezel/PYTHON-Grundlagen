# %%
age = int(input("Bitte gebe dein Alter ein: "))

# %%
if age < 18:
    print("Achtung, der Nutzer ist jünger als 18")
elif age == 18:
    print("Der Nutzer ist exakt 18")
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8792\2689565700.py in <module>
# ----> 1 if age < 18:
#       2     print("Achtung, der Nutzer ist jünger als 18")
#       3 elif age == 18:
#       4     print("Der Nutzer ist exakt 18")
#
# NameError: name 'age' is not defined

# %%
print("Programmende")
