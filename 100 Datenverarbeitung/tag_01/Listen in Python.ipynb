# %%
student1 = "Ulrich"
student2 = "Kevin"
student3 = "Markus"
student4 = "Ali"

# %%
Listenname = student1, student2, student3, student3,

# %%
students = ["Ulrich", "Kevin","Markus","Ali"]

# %%
print(students)
# Out:
# ['Ulrich', 'Kevin', 'Markus', 'Ali']
