# %%
print("strings in py")
# Out:
# strings in py

# %%
name = "denis"
print("ich bin:" + name)
# Out:
# ich bin:denis

# %%
print("ich bin: " + name)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_8372\3381549254.py in <module>
# ----> 1 print("ich bin: " + name)
#
# NameError: name 'name' is not defined

# %%
print("ich bin: " + "36")
# Out:
# ich bin: 36

# %%
age = 36
print("ich bin: " + age)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6640\3064292242.py in <module>
#       1 age = 36
# ----> 2 print("ich bin: " + age)
#
# TypeError: can only concatenate str (not "int") to str

# %%
print("ich bin: " + str(age))
# Out:
# ich bin: 36

# %%
print [1,2,3]
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_6640\675406127.py in <module>
# ----> 1 print [1,2,3]
#
# TypeError: 'builtin_function_or_method' object is not subscriptable
