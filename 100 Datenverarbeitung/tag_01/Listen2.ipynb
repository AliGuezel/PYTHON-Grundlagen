# %%
students = ["Ulrich","Kevin","Markus","Ali"]

# %%
print(students)
# Out:
# ['Ulrich', 'Kevin', 'Markus', 'Ali']

# %%
numbers = [1,2,3,4]

# %%
print(students[2])
# Out:
# Markus

# %%
print(students[0] + " und " + students[3])
# Out:
# Ulrich und Ali

# %%
print("hallo")
# Out:
# hallo

# %%
print(2)
# Out:
# 2

# %%
students.append("Kevin")

# %%
print(students)
# Out:
# ['Ulrich', 'Kevin', 'Markus', 'Ali', 'Kevin']

# %%
print(len(students))
# Out:
# 5

# %%
print(students)
# Out:
# ['Ulrich', 'Kevin', 'Markus', 'Ali', 'Kevin']

# %%
students.pop()
print(students)
# Out:
# ['Ulrich', 'Kevin', 'Markus', 'Ali']

# %%
my_first_variable = "Peter"
