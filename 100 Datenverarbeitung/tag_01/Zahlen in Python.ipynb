# %%
print()

# %%
print(10)
# Out:
# 10

# %%
print(5)
print(8)
# Out:
# 5
# 8

# %%
print(4+9)
# Out:
# 13

# %%
print(9-4)
print(5+1)
print(3+3)
print(5/4)
# Out:
# 5
# 6
# 6
# 1.25

# %%
print(5+5)
# Out:
# 10

# %%
print(1.56+3)
# Out:
# 4.5600000000000005

# %%
print()
